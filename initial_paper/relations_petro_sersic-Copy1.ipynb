# %%
import multiprocessing as mp
import numpy as np 
from scipy.special import gammaincinv, gamma, factorial

from astropy.modeling import models 
from astropy.table import Table
from astropy.modeling import models, fitting
from astropy.modeling import custom_model, powerlaws
from astropy.utils.console import ProgressBar
from astropy.convolution import convolve

from petrofit.models import sersic_enclosed, sersic_enclosed_inv, petrosian_profile, sersic_enclosed, make_grid, PSFModel
from petrofit.petrosian import Petrosian, PetrosianCorrection, calculate_petrosian,discrete_petrosian_r
from petrofit.fitting import model_to_image, fit_model
from petrofit.photometry import calculate_photometic_density,  make_radius_list
from petrofit.petrosian import Petrosian
from petrofit.utils import closest_value_index, get_interpolated_values
from scipy.interpolate import interp1d
from petrofit.petrosian import fraction_flux_to_r

# %matplotlib inline

from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = [10, 10]
plt.rcParams['image.origin'] = 'lower'
#plt.rcParams.update({'font.size': 17})


import matplotlib.pyplot as plt

SMALL_SIZE = 12
MEDIUM_SIZE = 15
BIGGER_SIZE = 20

#plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title


def savefig(filename):
    plt.savefig("plots/"+filename, dpi=70, bbox_inches = 'tight', pad_inches = 0.1)

# %%
run = False 

delta = 20
r_eff_list = [50]#np.arange(delta, 100 + delta, delta)
delta = 0.01
n_list = np.arange(0.2, 20 + delta, delta)

rows = []
if run:
    with ProgressBar(len(r_eff_list) * len(n_list), ipython_widget=True) as bar:
        for n_idx, n in enumerate(n_list):

            for r_eff_idx, r_eff in enumerate(r_eff_list):
                bar.update()

                b_n = gammaincinv(2. * n, 0.5)
                amplitude=1 #/np.exp(b_n)

                total_flux = sersic_enclosed(np.inf, amplitude, r_eff, n)
                enclosed_99 = total_flux*.99

                r_99 = sersic_enclosed_inv(enclosed_99, amplitude, r_eff, n)
                r_20 = sersic_enclosed_inv(enclosed_99*0.2, amplitude, r_eff, n)
                r_80 = sersic_enclosed_inv(enclosed_99*0.8, amplitude, r_eff, n)
                r_90 = sersic_enclosed_inv(enclosed_99*0.9, amplitude, r_eff, n)
                r_50 = sersic_enclosed_inv(enclosed_99*0.5, amplitude, r_eff, n)

                oversample = 10000
                max_pix=int(r_90)*oversample

                r_list = make_radius_list(
                            max_pix=max_pix, # Max pixel to go up to
                            n=max_pix,# the number of radii to produce
                )
                r_list /=oversample
                
                delta = ((3*r_99)-r_90)
                if delta > 1000:
                    delta /= 1000
                else:
                    delta = 1
                    
                r_list = list(r_list) + list(np.arange(r_90+delta, (3*r_99)+delta, delta))
                r_list = np.array(r_list)

                flux_arr = sersic_enclosed(r_list, amplitude, r_eff, n)
                area_arr = np.pi*(r_list**2)
                
                petrosian_list = petrosian_profile(r_list, r_eff, n)
                
                # Interpolate values
                
                eta = 0.2 
                idx = closest_value_index(eta, petrosian_list)
                r_petrosian = r_list[idx]
                
                
                #r_list_new, petrosian_list_new = get_interpolated_values(r_list, petrosian_list, num=len(r_list)*10, kind='linear')
                #idx = closest_value_index(eta, petrosian_list_new)
                #r_petrosian = r_list_new[idx]
                
                #f = interp1d(petrosian_list, r_list, kind='linear')
                #r_petrosian = f(eta)
                
                idx_list = np.where(petrosian_list <= eta)[0]

                #print(total_flux)
                epsilon = r_99 / r_petrosian
                p_corr = None#Petrosian(r_list, area_arr, flux_arr, epsilon=epsilon)
      
                p_corr_eta = eta
                p_corr_epsilon = epsilon
                p_corr_r_petrosian = r_petrosian
                p_corr_r_total_flux = r_petrosian * p_corr_epsilon
                f = interp1d(r_list, flux_arr, kind='linear')
                p_corr_total_flux = f(p_corr_r_total_flux)
                p_corr_r_20 = fraction_flux_to_r(r_list, flux_arr, p_corr_r_total_flux, fraction=0.2)
                p_corr_r_80 = fraction_flux_to_r(r_list, flux_arr, p_corr_r_total_flux, fraction=0.8)
                p_corr_r_half_light = fraction_flux_to_r(r_list, flux_arr, p_corr_r_total_flux, fraction=0.5)
                
                                
                p_uncorr_eta = eta
                p_uncorr_epsilon = 2
                p_uncorr_r_petrosian = r_petrosian
                p_uncorr_r_total_flux = r_petrosian * p_uncorr_epsilon
                f = interp1d(r_list, flux_arr, kind='linear')
                p_uncorr_total_flux = f(p_uncorr_r_total_flux)
                p_uncorr_r_20 = fraction_flux_to_r(r_list, flux_arr, p_uncorr_r_total_flux, fraction=0.2)
                p_uncorr_r_80 = fraction_flux_to_r(r_list, flux_arr, p_uncorr_r_total_flux, fraction=0.8)
                p_uncorr_r_half_light = fraction_flux_to_r(r_list, flux_arr, p_uncorr_r_total_flux, fraction=0.5)
                

                rows.append([
                    n, r_eff, amplitude, total_flux, r_99, r_20, r_80, 5 *np.log10(r_80 / r_20),
                    p_corr_eta, p_corr_epsilon, p_corr_r_petrosian, p_corr_r_half_light, p_corr_r_total_flux, p_corr_total_flux, p_corr_r_20, p_corr_r_80, 5 *np.log10(p_corr_r_80 / p_corr_r_20), 
                    p_uncorr_eta, p_uncorr_epsilon, p_uncorr_r_petrosian, p_uncorr_r_half_light, p_uncorr_r_total_flux, p_uncorr_total_flux, p_uncorr_r_20, p_uncorr_r_80, 5 *np.log10(p_uncorr_r_80 / p_uncorr_r_20),
                ])



                assert not np.any(np.isnan(np.array(rows[-1]))), "{}".format(n)
                #plt.plot(r_list, petrosian_list)
                #plt.show()

    names = [
        "sersic_n", "sersic_r_eff", "sersic_amplitude", "sersic_total_flux_99", "sersic_r_99", "sersic_r_20", "sersic_r_80", "sersic_c2080",
        "corr_eta", "corr_epsilon", "corr_r_petrosian", "corr_r_half_light", "corr_r_total_flux", "corr_total_flux", "corr_r_20", "corr_r_80", "corr_c2080",
        'uncorr_eta', 'uncorr_epsilon', 'uncorr_r_petrosian', 'uncorr_r_half_light', 'uncorr_r_total_flux', 'uncorr_total_flux', 'uncorr_r_20', 'uncorr_r_80', 'uncorr_c2080'
    ]

    t = Table(rows=rows, names=names)

    plt.show()
    print("done")
else:
    t = Table.read('pure_grid.csv')

# %%
#t.write('pure_grid.csv', overwrite=True)
t = Table.read('pure_grid.csv')

# %%
x = list(t[np.where(t['sersic_n'] < 15)]['uncorr_c2080']) 
y = list(t[np.where(t['sersic_n'] < 15)]['corr_c2080'])

x = np.array(x)
y = np.array(y)

plt.scatter(x, y, marker='o', c='black', label='data')

# initialize a linear fitter
fit = fitting.LevMarLSQFitter()
fit = fitting.LinearLSQFitter()

# initialize a linear model
exp1d = models.Exponential1D()
power = powerlaws.SmoothlyBrokenPowerLaw1D()

line_init =  models.Polynomial1D(6)

fitted_line = fit(line_init, x, y)

c_relation = fitted_line

print(fitted_line.param_names)
print(fitted_line.parameters)

arr = np.arange(min(x), max(x)+0.1, 0.1)

plt.plot(x, fitted_line(x), c='red', linewidth=2,
         label='Fitted Model'.format(*fitted_line.parameters))

plt.title("Corrected vs Uncorrected Concentration Index")
plt.xlabel("Uncorrected C2080")
plt.ylabel("Corrected C2080")
plt.legend()

savefig("corr_vs_uncorr_c2080.png")
# Out:
# ('c0', 'c1', 'c2', 'c3', 'c4', 'c5', 'c6')
# [ 8.67688265e-01 -1.02049948e+00  1.89002119e+00 -9.00083318e-01
#   2.25793520e-01 -2.83180263e-02  1.48735217e-03]

# %%
plt.plot(x, (y- fitted_line(x))/y, c='red', linewidth=2,
         label='Fitted Model'.format(*fitted_line.parameters))
plt.ylim(-0.05, 0.05)
# Out:
# (-0.05, 0.05)

# %%
c_relation.__repr__()
# Out:
# '<Polynomial1D(6, c0=2.2657378, c1=-3.61823723, c2=3.82707985, c3=-1.64341018, c4=0.38099834, c5=-0.04508192, c6=0.00222111)>'

# %%
figsize = [10*2., 10*1]
fig, ax = plt.subplots(1, 2, figsize=figsize)

plt.sca(ax[0])

max_n = 4
x = list(t[np.where(t['sersic_n'] < max_n)]['corr_c2080']) 
y = list(t[np.where(t['sersic_n'] < max_n)]['sersic_n'])

x = np.array(x)
y = np.array(y)

plt.scatter(x, y, marker='o', c='black', label='data')

# initialize a linear fitter
fit = fitting.LevMarLSQFitter()
#fit = fitting.LinearLSQFitter()

# initialize a linear model
exp1d = models.Exponential1D()
power = powerlaws.BrokenPowerLaw1D()

line_init =  models.Polynomial1D(3)

fitted_line = fit(line_init, x, y, maxiter=100000, acc=0)

print(fitted_line.param_names)
print(fitted_line.parameters)

arr = np.arange(min(x), max(x), 0.1)

plt.plot(x, fitted_line(x), c='red', linewidth=2,
         label='Fitted Model'.format(*fitted_line.parameters))

plt.title("Corrected Concentration Index vs Sérsic Index")
plt.xlabel("Corrected C2080")
plt.ylabel("Sérsic Index n")
plt.legend()

###########################################################

# plt.sca(ax[1])

# x = list(t[np.where(t['sersic_n'] < 15)]['uncorr_c2080']) 
# y = list(t[np.where(t['sersic_n'] < 15)]['sersic_n'])

# x = np.array(x)
# y = np.array(y)

# plt.scatter(x, y, marker='o', c='black', label='data')

# # initialize a linear fitter
# fit = fitting.LevMarLSQFitter()
# fit = fitting.LinearLSQFitter()

# # initialize a linear model
# exp1d = models.Exponential1D()
# power = powerlaws.SmoothlyBrokenPowerLaw1D()

# line_init =  models.Polynomial1D(5)

# fitted_line = fit(line_init, x, y)

# print(fitted_line.param_names)
# print(fitted_line.parameters)

# arr = np.arange(min(x), max(x), 0.1)

# plt.plot(arr, fitted_line(arr), c='red', linewidth=2,
#          label='Fitted Model'.format(*fitted_line.parameters))

# plt.title("Uncorrected Concentration Index vs Sérsic Index")
# plt.xlabel("Uncorrected C2080")
# plt.ylabel("Sérsic Index n")
# plt.legend()


# savefig("c2080_vs_n.png")
plt.xlim(min(x)-0.5, min(x)+1)
plt.show()
plt.plot(x, (y- fitted_line(x))/y, c='red', linewidth=2,
         label='Fitted Model'.format(*fitted_line.parameters))
plt.ylim(-0.05, 0.05)
# Out:
# WARNING: Model is linear in parameters; consider using linear fitting methods. [astropy.modeling.fitting]
# ('c0', 'c1', 'c2', 'c3')
# [-0.58078614  0.32568069  0.06772027  0.00735673]
# (-0.05, 0.05)

# %%
@custom_model
def Robel(
    x,  x_break=8, amplitude=1, x_0=1, alpha=1, expamplitude=1., tau=1.,
    c0=0., c1=0., c2=0., c3=0., c4=0., c5=0., c6=0.):
    """One dimensional broken power law model function"""
    
    x = np.array(x)
    
    y = np.zeros_like(x)
    
    idx_low = np.where(x < x_break)[0]
    idx_hi = np.where(x >= x_break)[0]
    
    y[idx_low] = (models.Polynomial1D(6, c0=c0, c1=c1, c2=c2, c3=c3, c4=c4, c5=c5, c6=c6))(x[idx_low])
    y[idx_hi] = (powerlaws.PowerLaw1D(amplitude=amplitude, x_0=x_0, alpha=alpha) * models.Exponential1D(amplitude=expamplitude, tau=tau))(x[idx_hi])
    
    return y

# %%
@custom_model
def Robel(
    x,
        amplitude_0=1., tau_0=1., amplitude_1=1., x_break_1=1., 
        alpha_1_1=1., alpha_2_1=1., 
        c0_2=0., c1_2=0., c2_2=0., c3_2=0., c4_2=0., c5_2=0.):
    x = c_relation(x)
    model = models.Exponential1D(amplitude_0, tau_0) * powerlaws.BrokenPowerLaw1D( amplitude_1, x_break_1, alpha_1_1, alpha_2_1)
    model *= models.Polynomial1D(5,  c0=c0_2, c1=c1_2, c2=c2_2, c3=c3_2, c4=c4_2, c5=c5_2)
    return model(x)

# %%
', '.join("""1.73933787e+00  7.60633484e-01  1.73933783e+00  2.41329438e+00
  1.20849066e+00  1.46517362e+00  3.74693318e-02 -8.30128155e-03
  5.83107690e-04  3.50938676e-05 -6.53993888e-06  2.61294276e-07""".split())
# Out:
# '1.73933787e+00, 7.60633484e-01, 1.73933783e+00, 2.41329438e+00, 1.20849066e+00, 1.46517362e+00, 3.74693318e-02, -8.30128155e-03, 5.83107690e-04, 3.50938676e-05, -6.53993888e-06, 2.61294276e-07'

# %%
max_n = 15
print('corr_c2080')
x = list(t[np.where(t['sersic_n'] < max_n)]['sersic_n']) 
y = list(t[np.where(t['sersic_n'] < max_n)]['corr_epsilon'])

x = np.array(x)
y = np.array(y)

#plt.scatter(x, y, marker='o', c='black', label='data')

# initialize a linear fitter
fit = fitting.LevMarLSQFitter()
#fit = fitting.LinearLSQFitter()

# initialize a linear model
exp1d = models.Exponential1D()
power = powerlaws.BrokenPowerLaw1D()

line_init =  exp1d*power*models.Polynomial1D(5)

#line_init = Robel(1.73933787e+00, 7.60633484e-01, 1.73933783e+00, 2.41329438e+00, 1.20849066e+00, 1.46517362e+00, 3.74693318e-02, -8.30128155e-03, 5.83107690e-04, 3.50938676e-05, -6.53993888e-06, 2.61294276e-07)
fitted_line = fit(line_init, x, y, maxiter=100000, acc=0)

print(fitted_line.param_names)
print(fitted_line.parameters)


arr = np.array(list(np.arange(min(x), max(x), 0.1))+[max(x)])

plt.scatter(x, (y-fitted_line(x))/y, c='red', linewidth=2,
         label='Fitted Model'.format(*fitted_line.parameters))

plt.ylim(-.5, .5)
plt.axhline(-.05)
plt.axhline(.05)
plt.show()

plt.scatter(x, y, marker='o', c='black', label='data')
plt.plot(x, fitted_line(x), c='red', linewidth=2,
         label='Fitted Model'.format(*fitted_line.parameters))

plt.xlim(0.5, max(list(t[np.where(t['sersic_n'] < 5)]['corr_c2080'])))
plt.ylim(0.5, max(list(t[np.where(t['sersic_n'] < 5)]['corr_epsilon'])))

plt.show()


plt.scatter(x, y, marker='o', label='data',  s=180, facecolors='none', edgecolors='b')

x_break = x[-1]

x = np.array(t['corr_c2080'])
y = np.array(t['corr_epsilon'])
plt.scatter(x, y, marker='o', label='data')

plt.plot(x, fitted_line(x), c='red', linewidth=2,
         label='Fitted Model'.format(*fitted_line.parameters))

plt.axvline(x_break)
# Out:
# corr_c2080
# ('amplitude_0', 'tau_0', 'amplitude_1', 'x_break_1', 'alpha_1_1', 'alpha_2_1', 'c0_2', 'c1_2', 'c2_2', 'c3_2', 'c4_2', 'c5_2')
# [ 2.13350942e+01  2.26656304e+00  2.13350942e+01  1.99997988e+00
#   2.97287514e-02  3.75707170e-02  1.89786250e-03  6.72176491e-04
#  -3.49827332e-05 -3.37055697e-07  5.25456735e-08 -9.46758971e-10]

# %%
repr(fitted_line)
# Out:
# '<CompoundModel(amplitude_0=1.86612135, tau_0=0.80928947, amplitude_1=1.86612134, x_break_1=3.03567532, alpha_1_1=1.25846255, alpha_2_1=1.44951868, c0_2=0.02661735, c1_2=-0.00528177, c2_2=0.00039502, c3_2=0.00002165, c4_2=-0.00000453, c5_2=0.00000022)>'

# %%
max_n = 15
print('corr_c2080')
x = list(t[np.where(t['sersic_n'] < max_n)]['uncorr_c2080']) 
y = list(t[np.where(t['sersic_n'] < max_n)]['corr_epsilon'])

x = np.array(x)
y = np.array(y)

#plt.scatter(x, y, marker='o', c='black', label='data')

# initialize a linear fitter
fit = fitting.LevMarLSQFitter()
#fit = fitting.LinearLSQFitter()

# initialize a linear model
exp1d = models.Exponential1D()
power = powerlaws.BrokenPowerLaw1D()

# line_init =  exp1d*power*models.Polynomial1D(5)

# fitted_line = fit(line_init, x, y, maxiter=10000, acc=0)

print(fitted_line.param_names)
print(fitted_line.parameters)



arr = np.array(list(np.arange(min(x), max(x), 0.1))+[max(x)])

plt.scatter(x, (y-fitted_line(c_relation(x)))/y, c='red', linewidth=2,
         label='Fitted Model'.format(*fitted_line.parameters))

plt.ylim(-.5, .5)
plt.axhline(-.05)
plt.axhline(.05)
plt.show()

plt.scatter(x, y, marker='o', c='black', label='data')
plt.plot(x, fitted_line(c_relation(x)), c='red', linewidth=2,
         label='Fitted Model'.format(*fitted_line.parameters))

plt.xlim(0.5, max(list(t[np.where(t['sersic_n'] < 5)]['corr_c2080'])))
plt.ylim(0.5, max(list(t[np.where(t['sersic_n'] < 5)]['corr_epsilon'])))

plt.show()


plt.scatter(x, y, marker='o', label='data',  s=180, facecolors='none', edgecolors='b')

x_break = x[-1]

# x = np.array(t['uncorr_c2080'])
# y = np.array(t['corr_epsilon'])
plt.scatter(x, y, marker='o', label='data')

plt.scatter(x, fitted_line(c_relation(x)), c='red', linewidth=2,
         label='Fitted Model'.format(*fitted_line.parameters))

plt.axvline(x_break)
# Out:
# corr_c2080
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# ('amplitude_0', 'tau_0', 'amplitude_1', 'x_break_1', 'alpha_1_1', 'alpha_2_1', 'c0_2', 'c1_2', 'c2_2', 'c3_2', 'c4_2', 'c5_2')
# [ 1.73933787e+00  7.60633484e-01  1.73933783e+00  2.41329438e+00
#   1.20849066e+00  1.46517362e+00  3.74693318e-02 -8.30128155e-03
#   5.83107690e-04  3.50938676e-05 -6.53993888e-06  2.61294276e-07]

# %%
if np.array(x_break):
    print(x)
# Out:
# <ipython-input-335-fdfad26b06d1>:1: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if np.array(x_break):

# %%
np.where(t['sersic_n'] == 5)
# Out:
# (array([99]),)

# %%
t['sersic_n']
# Out:
# <Column name='sersic_n' dtype='float64' length=400>
#                0.05
#                 0.1
# 0.15000000000000002
#                 0.2
#                0.25
#                 0.3
# 0.35000000000000003
#                 0.4
#                0.45
#                 0.5
#                0.55
#  0.6000000000000001
#                 ...
#  19.450000000000003
#  19.500000000000004
#               19.55
#                19.6
#  19.650000000000002
#  19.700000000000003
#  19.750000000000004
#                19.8
#               19.85
#  19.900000000000002
#  19.950000000000003
#  20.000000000000004

# %%
plt.plot(t['sersic_n'],t['sersic_c2080'] - t['corr_c2080'])

# %%
t.colnames
# Out:
# ['sersic_n',
#  'sersic_r_eff',
#  'sersic_amplitude',
#  'sersic_total_flux_99',
#  'sersic_r_99',
#  'sersic_r_20',
#  'sersic_r_80',
#  'sersic_c2080',
#  'corr_eta',
#  'corr_epsilon',
#  'corr_r_petrosian',
#  'corr_r_half_light',
#  'corr_r_total_flux',
#  'corr_total_flux',
#  'corr_r_20',
#  'corr_r_80',
#  'corr_c2080',
#  'uncorr_eta',
#  'uncorr_epsilon',
#  'uncorr_r_petrosian',
#  'uncorr_r_half_light',
#  'uncorr_r_total_flux',
#  'uncorr_total_flux',
#  'uncorr_r_20',
#  'uncorr_r_80',
#  'uncorr_c2080']

# %%
figsize = [10*3., 10*1]
fig, ax = plt.subplots(1, 3, figsize=figsize)

plt.sca(ax[0])

max_n = 15
print('corr_c2080')
x = list(t[np.where(t['sersic_n'] < max_n)]['corr_c2080']) 
y = list(t[np.where(t['sersic_n'] < max_n)]['corr_epsilon'])

x = np.array(x)
y = np.array(y)

plt.scatter(x, y, marker='o', c='black', label='data')

# initialize a linear fitter
fit = fitting.LevMarLSQFitter()
fit = fitting.LinearLSQFitter()

# initialize a linear model
exp1d = models.Exponential1D()
power = powerlaws.BrokenPowerLaw1D()

line_init =  models.Polynomial1D(10) 


fitted_line = fit(line_init, x, y)

print(fitted_line.param_names)
print(fitted_line.parameters)

arr = np.array(list(np.arange(min(x), max(x), 0.1))+[max(x)])

plt.plot(arr, fitted_line(arr), c='red', linewidth=2,
         label='Fitted Model'.format(*fitted_line.parameters))

plt.title("Corrected Concentration Index vs Epsilon")
plt.xlabel("Corrected C2080")
plt.ylabel("Epsilon")
plt.legend()

#plt.xlim(1, max(list(t[np.where(t['sersic_n'] < 5)]['corr_c2080'])))
#plt.ylim(1, max(list(t[np.where(t['sersic_n'] < 5)]['corr_epsilon'])))
###########################################################

plt.sca(ax[1])
print('uncorr_c2080')
x = list(t[np.where(t['sersic_n'] < max_n)]['uncorr_c2080']) 
y = list(t[np.where(t['sersic_n'] < max_n)]['corr_epsilon'])

x = np.array(x)
y = np.array(y)

plt.scatter(x, y, marker='o', c='black', label='data')

# initialize a linear fitter
fit = fitting.LevMarLSQFitter()
#fit = fitting.LinearLSQFitter()

# initialize a linear model
exp1d = models.Exponential1D()
power = powerlaws.BrokenPowerLaw1D()

line_init =  power * models.Polynomial1D(10) * exp1d

fitted_line = fit(line_init, x, y)

print(fitted_line.param_names)
print(fitted_line.parameters)

arr = np.array(list(np.arange(min(x), max(x), 0.1))+[max(x)])

plt.plot(arr, fitted_line(arr), c='red', linewidth=2,
         label='Fitted Model'.format(*fitted_line.parameters))

plt.title("Unorrected Concentration Index vs Epsilon")
plt.xlabel("Unorrected C2080")
plt.ylabel("Epsilon")
plt.legend()


###########################################################

plt.sca(ax[2])
print('sersic_n')
x = list(t[np.where(t['sersic_n'] < max_n)]['sersic_n']) 
y = list(t[np.where(t['sersic_n'] < max_n)]['corr_epsilon'])

x = np.array(x)
y = np.array(y)

plt.scatter(x, y, marker='o', c='black', label='data')

# initialize a linear fitter
fit = fitting.LevMarLSQFitter()
#fit = fitting.LinearLSQFitter()

# initialize a linear model
exp1d = models.Exponential1D()
power = powerlaws.BrokenPowerLaw1D()

line_init =  exp1d * models.Polynomial1D(5) 

fitted_line = fit(line_init, x, y, maxiter=10000, acc=0)

print(fitted_line.param_names)
print(fitted_line.parameters)

arr = np.array(list(np.arange(min(x), max(x), 0.1))+[max(x)])

plt.plot(arr, fitted_line(arr), c='red', linewidth=2,
         label='Fitted Model'.format(*fitted_line.parameters))

plt.title("Sérsic Index vs Epsilon")
plt.xlabel("Sérsic Index n")
plt.ylabel("Epsilon")
plt.legend()

savefig("epsilon_vs_n_and_c2080.png")
plt.show()

plt.scatter(x, (y-fitted_line(x))/y, c='red', linewidth=2,
         label='Fitted Model'.format(*fitted_line.parameters))

plt.ylim(-.5, .5)
plt.axhline(-.05)
plt.axhline(.05)
plt.show()

#[2705.309638     10.40882817  -11.83192596  -14.75964505]
# Out:
# corr_c2080
# WARNING: The fit may be poorly conditioned
#  [astropy.modeling.fitting]
# ('c0', 'c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9', 'c10')
# [ 4.65272184e+02 -9.85151270e+02  8.61333801e+02 -4.06842466e+02
#   1.14079943e+02 -1.95129273e+01  1.99036608e+00 -1.09598303e-01
#   2.29833758e-03  1.73577810e-05  6.68823011e-08]
# uncorr_c2080
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# ('amplitude_0', 'x_break_0', 'alpha_1_0', 'alpha_2_0', 'c0_1', 'c1_1', 'c2_1', 'c3_1', 'c4_1', 'c5_1', 'c6_1', 'c7_1', 'c8_1', 'c9_1', 'c10_1')
# [ 1.43630933e+00  1.48512773e+00  1.00000000e+00  2.90067868e-01
#   1.84859037e+01  3.75137540e+01  1.59487770e+00 -1.05468632e+00
#  -3.50677980e-01 -6.95310815e-02 -9.76634326e-03 -6.92534046e-04
#   1.41946699e-04  8.23284536e-05  2.59075602e-05]
# sersic_n
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# ('amplitude_0', 'tau_0', 'c0_1', 'c1_1', 'c2_1', 'c3_1', 'c4_1', 'c5_1')
# [ 2.86538103e+02  2.29019376e+00  3.21148511e-03  9.76694339e-04
#  -4.68780274e-05 -8.89447791e-07  9.24676158e-08 -1.64167649e-09]

# %%
class CPower(powerlaws.ExponentialCutoffPowerLaw1D):
    def evaluate(self, x, *args, **kw):
        
         return super().evaluate(c_relation(x), *args, **kw)

# %%
x = list(t[np.where(t['sersic_n'] < 20)]['uncorr_c2080']) 
y = list(t[np.where(t['sersic_n'] < 20)]['corr_epsilon'])

x = np.array(x)
y = np.array(y)

plt.scatter(x, y, marker='o', c='black', label='data')

# initialize a linear fitter
fit = fitting.LevMarLSQFitter()
#fit = fitting.LinearLSQFitter()

# initialize a linear model
exp1d = models.Exponential1D()
power = powerlaws.BrokenPowerLaw1D()

line_init = power#CPower(2705.309638,     10.40882817 , -11.83192596  ,-14.75964505) 

fitted_line = fit(line_init, x, y)

print(fitted_line.param_names)
print(fitted_line.parameters)

arr = np.array(list(np.arange(min(x), max(x), 0.1))+[max(x)])

plt.plot(arr, fitted_line(arr), c='red', linewidth=2,
         label='Fitted Model'.format(*fitted_line.parameters))

plt.title("Corrected Concentration Index vs Epsilon")
plt.xlabel("Corrected C2080")
plt.ylabel("Epsilon")
plt.legend()
# Out:
# /home/robel/miniconda3/envs/petrofit/lib/python3.9/site-packages/astropy/modeling/powerlaws.py:120: RuntimeWarning: invalid value encountered in power
#   return amplitude * xx ** (-alpha)
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# ('amplitude', 'x_break', 'alpha_1', 'alpha_2')
# [158.39929707   5.58892927 -11.23809545 -39.16443298]

# %%
@custom_model
def f(n, c=1, k=1):
    b_n = gammaincinv(2. * n, 0.5)
    top = k*n*(np.exp(b_n)/(b_n)**(2*n))*gamma(2*n)
    bottom = ((c*gamma(2*n+1))/(b_n*gamma(2*n)))**n
    return (top / bottom)

# %%
@custom_model
def f(n, k=1):
    b_n = gammaincinv(2. * n, 0.5)
    top = k*n*(np.exp(b_n)/(b_n)**(2*n))*gamma(2*n)
    bottom = ((0.8*n**2 - 1.6*n - 1)/b_n)**n
    return (top / bottom)

# %%
@custom_model
def f(n, k=1):
    b_n = gammaincinv(2. * n, 0.5)
    top = k*n*(np.exp(b_n)/(b_n)**(2*n))*gamma(2*n)
    bottom = ((0.8*n**2)/b_n)**n
    return (top / bottom)

# %%
@custom_model
def f(n, c0=0., c1=0., c2=0.):
    b_n = gammaincinv(2. * n, 0.5)
    p = models.Polynomial1D(4, c0=c0, c1=c1, c2=c2)
    return (p(n))**n

# %%
@custom_model
def f(n, c0=1., c1=1., c2=1., 
      x_break=1,
      alpha_2=1):
    alpha_1=n
    b_n = gammaincinv(2. * n, 0.5)
    poly = models.Polynomial1D(2, c0=c0, c1=c1, c2=c2)
    power = powerlaws.BrokenPowerLaw1D(1., x_break, alpha_1, alpha_2)
    return power(n)*poly(n)

# %%
@custom_model
def f(n, c0=1., c1=1., c2=1., 
      amplitude=1,
      tau=1):
    b_n = gammaincinv(2. * n, 0.5)
    poly = models.Polynomial1D(2, c0=c0, c1=c1, c2=c2)
    exp1d = models.Exponential1D(amplitude, tau)
    return exp1d(poly(n))

# %%
@custom_model
def f(n, k=1):
    b_n = gammaincinv(2. * n, 0.5)
    top = k*n*(np.exp(b_n)/(b_n)**(2*n))*gamma(2*n)
    bottom = (-1.6*(n + 0.5)/b_n)**n
    return (k / bottom)

# %%
x = list(t[np.where(t['sersic_n'] <15)]['sersic_n']) 
y = list(t[np.where(t['sersic_n'] < 15)]['corr_epsilon'])

x = np.array(x)
y = np.array(y)

plt.scatter(x, y, marker='o', c='black', label='data')

# initialize a linear fitter
fit = fitting.LevMarLSQFitter()
#fit = fitting.LinearLSQFitter()

# initialize a linear model
exp1d = models.Exponential1D()
power = powerlaws.BrokenPowerLaw1D()

line_init = f()#CPower(2705.309638,     10.40882817 , -11.83192596  ,-14.75964505) 
line_init = models.Polynomial1D(5) * exp1d
fitted_line = fit(line_init, x, y, maxiter=10000, acc=0)

x = list(t[np.where(t['sersic_n'] <15)]['sersic_n']) 
y = list(t[np.where(t['sersic_n'] < 15)]['corr_epsilon'])

x = np.array(x)
y = np.array(y)


print(fitted_line.param_names)
print(fitted_line.parameters)

arr = np.array(list(np.arange(min(x), max(x), 0.1))+[max(x)])

plt.plot(x, fitted_line(x), c='red', linewidth=2,
         label='Fitted Model'.format(*fitted_line.parameters))

plt.title("Corrected Concentration Index vs Epsilon")
plt.xlabel("Corrected C2080")
plt.ylabel("Epsilon")
plt.legend()
# Out:
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# ('c0_0', 'c1_0', 'c2_0', 'c3_0', 'c4_0', 'c5_0', 'amplitude_1', 'tau_1')
# [ 3.20851756e-03  9.74265580e-04 -4.74967359e-05 -8.46260583e-07
#   9.16091207e-08 -1.63835627e-09  2.86780146e+02  2.28714648e+00]

# %%
plt.scatter(x, (y-fitted_line(x))/y, c='red', linewidth=2,
         label='Fitted Model'.format(*fitted_line.parameters))

plt.ylim(-.5, .5)
plt.axhline(-.05)
plt.axhline(.05)
plt.show()

# %%
r_eff=25
figsize = [10*3., 10*3]
fig, ax = plt.subplots(3, 3, figsize=figsize)

r_list_half = np.arange(0, 51, 1)

r_list = list(-r_list_half) + list(r_list_half)
r_list = np.array(list(sorted(np.unique(np.array(r_list)))))


for i, n in enumerate([0.5, 1, 4]):
    plt.sca(ax[0, i])
    b_n = gammaincinv(2. * n, 0.5)
    amplitude=1 /np.exp(b_n)

    model = models.Sersic1D(amplitude, r_eff=r_eff, n=n)


    i_list =  model(abs(r_list))
    plt.plot(r_list, i_list, c='black', linewidth=4, label="Sersic Profile with n={}".format(n))
    #plt.fill_between(r_list, i_list, color='b', alpha=0.1)
    #plt.bar(r_list, i_list, alpha=0.3)
    
    psf = models.Moffat1D(amplitude=1, gamma=1, alpha=0.5)(r_list)
    psf = psf/psf.sum()
    con_list = convolve(i_list, psf)

    plt.plot(r_list, con_list, c='r', linewidth=6, label="Moffat convolved Sersic Profile".format(n))
    #plt.fill_between(r_list, con_list, color='r', alpha=0.3)
    #plt.bar(r_list, con_list, width=0.6, color='r', alpha=0.3)
    
    plt.xlim(-50,50)
    plt.title("Sérsic Profile n = {}".format(n))
    plt.xlabel("Radius r")
    plt.ylabel("I(r)")
    plt.legend()
    
    plt.sca(ax[1, i])
    half_idx = r_list_half.size-1
    
    f_list = [sum(i_list[half_idx: half_idx+i]) for i in range(half_idx+1)]
    f_con_list = [sum(con_list[half_idx: half_idx+i]) for i in range(half_idx+1)]
    
    plt.plot(r_list_half, f_list, c='black', linewidth=4, label="Sersic Profile with n={}".format(n))
    plt.plot(r_list_half, f_con_list, c='r', linewidth=6, label="Moffat convolved Sersic Profile".format(n))
    #plt.fill_between(r_list_half, f_con_list, color='r', alpha=0.3)
    
    plt.title("Curve of Growth n = {}".format(n))
    plt.xlabel("Radius r")
    plt.ylabel("L(<r)")
    plt.legend()
    
    plt.sca(ax[2, i])
    
    area = [np.pi*i**2 for i in range(half_idx+1)]
    
    p = calculate_petrosian(area, f_list)
    p_con = calculate_petrosian(area, f_con_list)
    
    plt.plot(r_list_half, p, c='black', linewidth=4, label="Sersic Profile with n={}".format(n))
    plt.plot(r_list_half, p_con, c='r', linewidth=6, label="Moffat convolved Sersic Profile".format(n))
    #plt.fill_between(r_list_half, p_con, color='r', alpha=0.3)
    
    plt.title("Petrosian n = {}".format(n))
    plt.xlabel("Radius r")
    plt.ylabel("$\eta$(r)")
    plt.legend()
    
    
    
    
savefig("psf_effect_sersic.png")

# %% [markdown]
# # Original fit

# %%
# import numpy as np 
# from petrofit.petrosian import PetrosianCorrection
# from astropy.modeling import models, fitting

# %matplotlib inline

# from matplotlib import pyplot as plt
# plt.rcParams['figure.figsize'] = [10, 10]
# plt.rcParams['image.origin'] = 'lower'



pc = PetrosianCorrection("concentration_index_grid_no_psf.yaml")

keyx = 'c_index'
keyy = 'n'

x = []
y = []

# x = t[np.where(t['uncorr_c2080'] < 40.5)]['sersic_n']
# y = t[np.where(t['uncorr_c2080'] < 40.5)]['corr_epsilon']

x = list(t[np.where(t['sersic_n'] < 20)]['uncorr_c2080']) 
y = list(t[np.where(t['sersic_n'] < 20)]['corr_c2080'])

# for i, key in enumerate(list(pc.grid.keys())[:]):
#     if key < 10 or key > 90:
#         continue
#     a = (i+2) / len(pc.grid)
#     data = pc.grid[key]
#     plt.scatter(data[keyx], np.array(data[keyy]), c='black', alpha=a, label='r_eff={}'.format(key))

#     x += data[keyx]
#     y += data[keyy]

x = np.array(x)
y = np.array(y)

plt.scatter(x, y, marker='x')
#plt.plot(data[keyx], 10.0**(-1.7) * np.array(data[keyx])**3.5)

# initialize a linear fitter
fit = fitting.LevMarLSQFitter()
#fit = fitting.LinearLSQFitter()
# initialize a linear model
exp1d = models.Exponential1D()
#line_init = models.Exponential1D() + models.Const1D()

power = powerlaws.SmoothlyBrokenPowerLaw1D()
#line_init = models.Polynomial1D(5)
line_init =  models.Polynomial1D(4)

fitted_line = fit(line_init, x, y)

print(fitted_line.param_names)
print(fitted_line.parameters)

arr = np.arange(min(x)*0.8, max(x)*1.05, 0.1)

plt.plot(arr, fitted_line(arr), c='red', label='Fitted Exponential'.format(*fitted_line.parameters))
#plt.plot(arr, 0.1102*np.exp(arr/1.25))

plt.title("Relationship b/w Concentration Index and Sersic Index")
plt.xlabel("C2080")
plt.ylabel("Sersic Index n")
plt.legend()

savefig("concentration_index_vs_n.png")

print("range_c2080 = ({:.2f}, {:.2f})".format(x.min(), x.max()))

#plt.scatter(t['corr_c2080'], t['sersic_n'])
#plt.scatter(t['uncorr_c2080'], t['sersic_n'], alpha=0.3)
#plt.scatter(t['uncorr_c2080'], t['corr_c2080'], alpha=0.3)


#plt.scatter(py2, (0.12255 * np.exp(np.array(py2)/1.29494)) - 0.04285)
# Out:
# WARNING: Model is linear in parameters; consider using linear fitting methods. [astropy.modeling.fitting]
# ('c0', 'c1', 'c2', 'c3', 'c4')
# [ 2.59027449 -2.49916681  1.69257448 -0.36420234  0.03114332]
# range_c2080 = (1.51, 6.26)

# %%
# import numpy as np 
# from petrofit.petrosian import PetrosianCorrection
# from astropy.modeling import models, fitting

# %matplotlib inline

# from matplotlib import pyplot as plt
# plt.rcParams['figure.figsize'] = [10, 10]
# plt.rcParams['image.origin'] = 'lower'



pc = PetrosianCorrection("concentration_index_grid_no_psf.yaml")

keyx = 'c_index'
keyy = 'n'

x = []
y = []

# x = t[np.where(t['uncorr_c2080'] < 40.5)]['sersic_n']
# y = t[np.where(t['uncorr_c2080'] < 40.5)]['corr_epsilon']

x = list(t[np.where(t['sersic_n'] < 20)]['uncorr_c2080']) 
y = list(t[np.where(t['sersic_n'] < 20)]['sersic_n'])

# for i, key in enumerate(list(pc.grid.keys())[:]):
#     if key < 10 or key > 90:
#         continue
#     a = (i+2) / len(pc.grid)
#     data = pc.grid[key]
#     plt.scatter(data[keyx], np.array(data[keyy]), c='black', alpha=a, label='r_eff={}'.format(key))

#     x += data[keyx]
#     y += data[keyy]

x = np.array(x)
y = np.array(y)

plt.scatter(x, y, marker='x')
#plt.plot(data[keyx], 10.0**(-1.7) * np.array(data[keyx])**3.5)

# initialize a linear fitter
fit = fitting.LevMarLSQFitter()
fit = fitting.LinearLSQFitter()
# initialize a linear model
exp1d = models.Exponential1D()
#line_init = models.Exponential1D() + models.Const1D()

poly = models.Polynomial1D(5) #*line_init
power = powerlaws.SmoothlyBrokenPowerLaw1D()
#line_init = models.Polynomial1D(5)
line_init = poly

fitted_line = fit(line_init, x, y)

print(fitted_line.param_names)
print(fitted_line.parameters)

arr = np.arange(min(x)*0.8, max(x)*1.05, 0.1)

plt.plot(arr, fitted_line(arr), c='red', label='Fitted Exponential'.format(*fitted_line.parameters))
#plt.plot(arr, 0.1102*np.exp(arr/1.25))

plt.title("Relationship b/w Concentration Index and Sersic Index")
plt.xlabel("C2080")
plt.ylabel("Sersic Index n")
plt.legend()

savefig("concentration_index_vs_n.png")

print("range_c2080 = ({:.2f}, {:.2f})".format(x.min(), x.max()))

#plt.scatter(t['corr_c2080'], t['sersic_n'])
#plt.scatter(t['uncorr_c2080'], t['sersic_n'], alpha=0.3)
#plt.scatter(t['uncorr_c2080'], t['corr_c2080'], alpha=0.3)


#plt.scatter(py2, (0.12255 * np.exp(np.array(py2)/1.29494)) - 0.04285)
# Out:
# ('c0', 'c1', 'c2', 'c3', 'c4', 'c5')
# [-16.19267113  26.9723873  -17.25286064   5.40982632  -0.81996916
#    0.04957303]
# range_c2080 = (1.51, 6.26)

# %%
# import numpy as np 
# from petrofit.petrosian import PetrosianCorrection
# from astropy.modeling import models, fitting

# %matplotlib inline

# from matplotlib import pyplot as plt
# plt.rcParams['figure.figsize'] = [10, 10]
# plt.rcParams['image.origin'] = 'lower'



pc = PetrosianCorrection("concentration_index_grid_no_psf.yaml")

keyx = 'c_index'
keyy = 'n'

x = []
y = []

# x = t[np.where(t['uncorr_c2080'] < 40.5)]['sersic_n']
# y = t[np.where(t['uncorr_c2080'] < 40.5)]['corr_epsilon']

x = list(t[np.where(t['sersic_n'] < 20)]['corr_c2080']) 
y = list(t[np.where(t['sersic_n'] < 20)]['sersic_n'])

# for i, key in enumerate(list(pc.grid.keys())[:]):
#     if key < 10 or key > 90:
#         continue
#     a = (i+2) / len(pc.grid)
#     data = pc.grid[key]
#     plt.scatter(data[keyx], np.array(data[keyy]), c='black', alpha=a, label='r_eff={}'.format(key))

#     x += data[keyx]
#     y += data[keyy]

x = np.array(x)
y = np.array(y)

plt.scatter(x, y, marker='x')
#plt.plot(data[keyx], 10.0**(-1.7) * np.array(data[keyx])**3.5)

# initialize a linear fitter
fit = fitting.LevMarLSQFitter()
fit = fitting.LinearLSQFitter()
# initialize a linear model
exp1d = models.Exponential1D()
#line_init = models.Exponential1D() + models.Const1D()

poly = models.Polynomial1D(2) #*line_init
power = powerlaws.SmoothlyBrokenPowerLaw1D()
#line_init = models.Polynomial1D(5)
line_init = poly

fitted_line = fit(line_init, x, y)

print(fitted_line.param_names)
print(fitted_line.parameters)

arr = np.arange(min(x)*0.8, max(x)*1.05, 0.1)

plt.plot(arr, fitted_line(arr), c='red', label='Fitted Exponential'.format(*fitted_line.parameters))
#plt.plot(arr, 0.1102*np.exp(arr/1.25))

plt.title("Relationship b/w Concentration Index and Sersic Index")
plt.xlabel("C2080")
plt.ylabel("Sersic Index n")
plt.legend()

savefig("concentration_index_vs_n.png")

print("range_c2080 = ({:.2f}, {:.2f})".format(x.min(), x.max()))

#plt.scatter(t['corr_c2080'], t['sersic_n'])
#plt.scatter(t['uncorr_c2080'], t['sersic_n'], alpha=0.3)
#plt.scatter(t['uncorr_c2080'], t['corr_c2080'], alpha=0.3)


#plt.scatter(py2, (0.12255 * np.exp(np.array(py2)/1.29494)) - 0.04285)
# Out:
# ('c0', 'c1', 'c2')
# [-0.22010157  0.01188745  0.15262374]
# range_c2080 = (1.51, 11.46)

# %%
# import numpy as np 
# from petrofit.petrosian import PetrosianCorrection
# from astropy.modeling import models, fitting

# %matplotlib inline

# from matplotlib import pyplot as plt
# plt.rcParams['figure.figsize'] = [10, 10]
# plt.rcParams['image.origin'] = 'lower'



pc = PetrosianCorrection("concentration_index_grid_no_psf.yaml")

keyx = 'c_index'
keyy = 'n'

x = []
y = []

# x = t[np.where(t['uncorr_c2080'] < 40.5)]['sersic_n']
# y = t[np.where(t['uncorr_c2080'] < 40.5)]['corr_epsilon']

x = list(t[np.where(t['sersic_n'] < 20)]['uncorr_c2080']) 
y = list(t[np.where(t['sersic_n'] < 20)]['corr_epsilon'])

# for i, key in enumerate(list(pc.grid.keys())[:]):
#     if key < 10 or key > 90:
#         continue
#     a = (i+2) / len(pc.grid)
#     data = pc.grid[key]
#     plt.scatter(data[keyx], np.array(data[keyy]), c='black', alpha=a, label='r_eff={}'.format(key))

#     x += data[keyx]
#     y += data[keyy]

x = np.array(x)
y = np.array(y)

plt.scatter(x, y, marker='x')
#plt.plot(data[keyx], 10.0**(-1.7) * np.array(data[keyx])**3.5)

# initialize a linear fitter
fit = fitting.LevMarLSQFitter()
#fit = fitting.LinearLSQFitter()
# initialize a linear model
exp1d = models.Exponential1D()
#line_init = models.Exponential1D() + models.Const1D()

poly = models.Polynomial1D(5) #*line_init
power = powerlaws.BrokenPowerLaw1D()
#line_init = models.Polynomial1D(5)
line_init = power # models.Const1D()

fitted_line = fit(line_init, x, y)

print(fitted_line.param_names)
print(fitted_line.parameters)

arr = np.arange(min(x)*0.8, max(x)+.01, 0.1)

plt.plot(arr, fitted_line(arr), c='red', label='Fitted Exponential'.format(*fitted_line.parameters))
#plt.plot(arr, 0.1102*np.exp(arr/1.25))

plt.title("Relationship b/w Concentration Index and Sersic Index")
plt.xlabel("C2080")
plt.ylabel("Sersic Index n")
plt.legend()

savefig("concentration_index_vs_n.png")

print("range_c2080 = ({:.2f}, {:.2f})".format(x.min(), x.max()))

#plt.scatter(t['corr_c2080'], t['sersic_n'])
#plt.scatter(t['uncorr_c2080'], t['corr_epsilon'], alpha=0.3)
#plt.scatter(t['uncorr_c2080'], t['corr_c2080'], alpha=0.3)


#plt.scatter(py2, (0.12255 * np.exp(np.array(py2)/1.29494)) - 0.04285)
# Out:
# /home/robel/miniconda3/envs/petrofit/lib/python3.9/site-packages/astropy/modeling/powerlaws.py:120: RuntimeWarning: invalid value encountered in power
#   return amplitude * xx ** (-alpha)
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# ('amplitude', 'x_break', 'alpha_1', 'alpha_2')
# [158.39929707   5.58892927 -11.23809545 -39.16443298]
# range_c2080 = (1.51, 6.26)

# %%
# import numpy as np 
# from petrofit.petrosian import PetrosianCorrection
# from astropy.modeling import models, fitting

# %matplotlib inline

# from matplotlib import pyplot as plt
# plt.rcParams['figure.figsize'] = [10, 10]
# plt.rcParams['image.origin'] = 'lower'



pc = PetrosianCorrection("concentration_index_grid_no_psf.yaml")

keyx = 'c_index'
keyy = 'n'

x = []
y = []

# x = t[np.where(t['uncorr_c2080'] < 40.5)]['sersic_n']
# y = t[np.where(t['uncorr_c2080'] < 40.5)]['corr_epsilon']

x = list(t[np.where(t['sersic_n'] < 20)]['corr_c2080']) 
y = list(t[np.where(t['sersic_n'] < 20)]['corr_epsilon'])

# for i, key in enumerate(list(pc.grid.keys())[:]):
#     if key < 10 or key > 90:
#         continue
#     a = (i+2) / len(pc.grid)
#     data = pc.grid[key]
#     plt.scatter(data[keyx], np.array(data[keyy]), c='black', alpha=a, label='r_eff={}'.format(key))

#     x += data[keyx]
#     y += data[keyy]

x = np.array(x)
y = np.array(y)

plt.scatter(x, y, marker='x')
#plt.plot(data[keyx], 10.0**(-1.7) * np.array(data[keyx])**3.5)

# initialize a linear fitter
fit = fitting.LevMarLSQFitter()
#fit = fitting.LinearLSQFitter()
# initialize a linear model
exp1d = models.Exponential1D()
#line_init = models.Exponential1D() + models.Const1D()

poly = models.Polynomial1D(1) #*line_init
power = powerlaws.SmoothlyBrokenPowerLaw1D()
#line_init = models.Polynomial1D(5)
line_init =  power

fitted_line = fit(line_init, x, y)

print(fitted_line.param_names)
print(fitted_line.parameters)

arr = np.arange(min(x)*0.8, max(x)*1.0, 0.1)

plt.plot(arr, fitted_line(arr), c='red', label='Fitted Exponential'.format(*fitted_line.parameters))
#plt.plot(arr, 0.1102*np.exp(arr/1.25))

plt.title("Relationship b/w Concentration Index and Sersic Index")
plt.xlabel("C2080")
plt.ylabel("Sersic Index n")
plt.legend()

savefig("concentration_index_vs_n.png")

print("range_c2080 = ({:.2f}, {:.2f})".format(x.min(), x.max()))

#plt.scatter(t['corr_c2080'], t['sersic_n'])
#plt.scatter(t['uncorr_c2080'], t['sersic_n'], alpha=0.3)
#plt.scatter(t['uncorr_c2080'], t['corr_c2080'], alpha=0.3)


#plt.scatter(py2, (0.12255 * np.exp(np.array(py2)/1.29494)) - 0.04285)
# Out:
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# ('amplitude', 'x_break', 'alpha_1', 'alpha_2', 'delta')
# [ 21.63800437   6.98373787  -2.96664935 -17.6721778    0.37182551]
# range_c2080 = (1.51, 11.46)

# %%
# import numpy as np 
# from petrofit.petrosian import PetrosianCorrection
# from astropy.modeling import models, fitting

# %matplotlib inline

# from matplotlib import pyplot as plt
# plt.rcParams['figure.figsize'] = [10, 10]
# plt.rcParams['image.origin'] = 'lower'



pc = PetrosianCorrection("concentration_index_grid_no_psf.yaml")

keyx = 'c_index'
keyy = 'n'

x = []
y = []

# x = t[np.where(t['uncorr_c2080'] < 40.5)]['sersic_n']
# y = t[np.where(t['uncorr_c2080'] < 40.5)]['corr_epsilon']

x = list(t[np.where(t['sersic_n'] < 20)]['sersic_n']) 
y = list(t[np.where(t['sersic_n'] < 20)]['corr_epsilon'])

# for i, key in enumerate(list(pc.grid.keys())[:]):
#     if key < 10 or key > 90:
#         continue
#     a = (i+2) / len(pc.grid)
#     data = pc.grid[key]
#     plt.scatter(data[keyx], np.array(data[keyy]), c='black', alpha=a, label='r_eff={}'.format(key))

#     x += data[keyx]
#     y += data[keyy]

x = np.array(x)
y = np.array(y)

plt.scatter(x, y, marker='x')
#plt.plot(data[keyx], 10.0**(-1.7) * np.array(data[keyx])**3.5)

# initialize a linear fitter
fit = fitting.LevMarLSQFitter()
#fit = fitting.LinearLSQFitter()
# initialize a linear model
exp1d = models.Exponential1D()
#line_init = models.Exponential1D() + models.Const1D()

poly = models.Polynomial1D(2) #*line_init
power = powerlaws.SmoothlyBrokenPowerLaw1D()
#line_init = models.Polynomial1D(5)
line_init = exp1d #+ models.Const1D()

fitted_line = fit(line_init, x, y)

print(fitted_line.param_names)
print(fitted_line.parameters)

arr = np.arange(min(x)*0.8, max(x)*1.05, 0.1)

plt.plot(arr, fitted_line(arr), c='red', label='Fitted Exponential'.format(*fitted_line.parameters))
#plt.plot(arr, 0.1102*np.exp(arr/1.25))

plt.title("Relationship b/w Concentration Index and Sersic Index")
plt.xlabel("C2080")
plt.ylabel("Sersic Index n")
plt.legend()

savefig("concentration_index_vs_n.png")

print("range_c2080 = ({:.2f}, {:.2f})".format(x.min(), x.max()))

#plt.scatter(t['corr_c2080'], t['sersic_n'])
#plt.scatter(t['uncorr_c2080'], t['corr_epsilon'], alpha=0.3)
#plt.scatter(t['uncorr_c2080'], t['corr_c2080'], alpha=0.3)


#plt.scatter(py2, (0.12255 * np.exp(np.array(py2)/1.29494)) - 0.04285)
# Out:
# ('amplitude', 'tau')
# [3.85629928 2.4987389 ]
# range_c2080 = (0.05, 19.95)

# %%
# t = Table(rows=rows, names=names)

# %%
plt.scatter(t['uncorr_c2080'], t['corr_c2080'], marker='x')

# %%
plt.scatter(t['sersic_n'], t['corr_r_20']-t['sersic_r_20'], label='Uncorrected', alpha=t['sersic_r_eff']/t['sersic_r_eff'].max())

# %%
plt.scatter(t['sersic_c2080'], t['sersic_n'], label='Sersic', alpha=t['sersic_r_eff']/t['sersic_r_eff'].max())
plt.scatter(t['corr_c2080'], t['sersic_n'], label='Corrected', alpha=t['sersic_r_eff']/t['sersic_r_eff'].max())
plt.scatter(t['uncorr_c2080'], t['sersic_n'], label='Uncorrected', alpha=t['sersic_r_eff']/t['sersic_r_eff'].max())

#plt.plot(t['sersic_c2080'], 10.0**(-1.5) * np.array(t['sersic_c2080'])**3.5, label='Uncorrected')

plt.title("C2080 vs. Sersic n")
plt.legend()

# %%
plt.scatter(t['sersic_c2080'], t['corr_epsilon'], label='Sersic', marker='+')
plt.scatter(t['corr_c2080'], t['corr_epsilon'], label='Corrected', marker='x')
plt.scatter(t['uncorr_c2080'], t['corr_epsilon'], label='Uncorrected', marker='x')


plt.title("C2080 vs. Epsilon")
plt.legend()

# %%
plt.plot(t['sersic_n'], t['corr_epsilon'], label='Sersic', marker='x')
#plt.plot(t['sersic_n'], t['uncorr_epsilon'], label='Sersic', marker='o')

ft = t[t['sersic_n'] > 17]#13.5]

#ft = ft[ft['sersic_n']  < 15.5]

#plt.plot(ft['sersic_n'], ft['corr_epsilon'], label='Sersic', marker='x')

plt.title("Sersic n vs. Epsilon")
plt.legend()

# %%
ft
# Out:
# <Table length=6>
# sersic_n sersic_r_eff sersic_amplitude ...    uncorr_r_80        uncorr_c2080
# float64     int64          int64       ...      float64            float64
# -------- ------------ ---------------- ... ------------------ ------------------
#     17.5            5                1 ... 1.3085332697184318 20.583923845698934
#     18.0            5                1 ...  1.441706052070466 20.794383607821672
#     18.5            5                1 ... 1.5863382173102787 21.001978935878682
#     19.0            5                1 ...  1.743270343764545  21.20682371036608
#     19.5            5                1 ...  1.913396134377615 21.409024461125156
#     20.0            5                1 ...  2.097665342939869  21.60868101483697

# %%
ft['sersic_total_flux_99'] / ft['corr_r_petrosian']
# Out:
# <Column name='sersic_total_flux_99' dtype='float64' length=6>
# 893.6232513836267
# 822.4921384388161
# 757.7342488503787
# 698.7083053706396
# 644.8452045992843
# 595.6389798157521

# %%
plt.scatter(t['sersic_n'], t['sersic_c2080'], label='Sersic', alpha=t['sersic_r_eff']/t['sersic_r_eff'].max())
plt.scatter(t['sersic_n'], t['corr_c2080'], label='Corrected', alpha=t['sersic_r_eff']/t['sersic_r_eff'].max())
plt.scatter(t['sersic_n'], t['uncorr_c2080'], label='Uncorrected', alpha=t['sersic_r_eff']/t['sersic_r_eff'].max())

# %%
plt.scatter(t['sersic_n'], t['sersic_r_20'], label='Sersic', alpha=t['sersic_r_eff']/t['sersic_r_eff'].max())
plt.scatter(t['sersic_n'], t['corr_r_20'], label='Corrected', alpha=t['sersic_r_eff']/t['sersic_r_eff'].max())
plt.scatter(t['sersic_n'], t['uncorr_r_20'], label='Uncorrected', alpha=t['sersic_r_eff']/t['sersic_r_eff'].max())

# %%
from astropy.modeling import custom_model, powerlaws


def c2080_model(n):
    gamma_inv_1 = gammaincinv(2*n, g)

# %%
@custom_model
def log10_model(x, amplitude=1, tau=1):
    return amplitude * np.log10(x * tau)

@custom_model
def exp10(x, amplitude=1, tau=1):
    return amplitude * 10**(x * tau)

# %%
models.pow

# %%
fitted_line(arr)
# Out:
# array([ 0.3836068 ,  0.41246061,  0.44348471,  0.47684236,  0.51270908,
#         0.55127359,  0.5927388 ,  0.63732292,  0.68526052,  0.73680386,
#         0.79222413,  0.85181296,  0.91588389,  0.98477405,  1.05884593,
#         1.13848929,  1.22412319,  1.31619823,  1.41519889,  1.5216461 ,
#         1.63609996,  1.75916271,  1.89148188,  2.03375373,  2.18672686,
#         2.35120619,  2.52805718,  2.7182104 ,  2.92266639,  3.14250099,
#         3.3788709 ,  3.63301989,  3.90628524,  4.20010482,  4.51602467,
#         4.8557071 ,  5.22093948,  5.61364359,  6.03588577,  6.4898878 ,
#         6.97803857,  7.50290663,  8.06725377,  8.67404948,  9.32648663,
#        10.02799823, 10.78227552, 11.59328739, 12.46530124, 13.40290548,
#        14.41103363, 15.49499028, 16.66047905, 17.91363255, 19.26104466,
#        20.70980524])

# %%
poly.fixed
# Out:
# {'c0': False, 'c1': False}

# %%
np.max(t[np.where(t['uncorr_c2080'] < 4.5)]['uncorr_c2080'])
# Out:
# 4.434802433457039

# %%
plt.plot(r_list, pp, linewidth=10)
p.plot(1,1)

# %%
plt.scatter(t['sersic_n'], t['sersic_c2080'], label='Sersic', alpha=t['sersic_r_eff']/t['sersic_r_eff'].max())
plt.scatter(t['sersic_n'], t['corr_c2080'], label='Corrected', alpha=t['sersic_r_eff']/t['sersic_r_eff'].max())
plt.scatter(t['sersic_n'], t['uncorr_c2080'], label='Uncorrected', alpha=t['sersic_r_eff']/t['sersic_r_eff'].max())

# %%
def fraction_flux_to_r(r_list, flux_list, r_total_flux, fraction=0.5):
    """
    Given photometric values and `r_total_flux`, calculate radius which encloses a specified
    fraction of the total flux.

    Parameters
    ----------
    r_list : numpy.array
        Array of radii in pixels.

    flux_list : numpy.array
        Array of photometric flux values.

    r_total_flux : float
        Total flux radius (hint: `petrofit.petrosian.calculate_r_total_flux` can be used to measure this).

    fraction : float
        Fraction of flux total flux enclosed in target radius.

    Returns
    -------
    r_fraction_flux : float or numpy.nan
        Radius which encloses a specified fraction of the total flux (determined by the Petrosian profile).
    """

    if r_total_flux > max(r_list):
        return np.nan

    f = interp1d(r_list, flux_list, kind='nearest')
    total_flux = f(r_total_flux)
    fractional_flux = total_flux * fraction

    r_list_new, flux_list_new = r_list, flux_list#get_interpolated_values(r_list, flux_list, num=len(r_list)*4, kind='cubic' )

    #idx = abs(flux_list_new - fractional_flux).argmin()
    idx = closest_value_index(fractional_flux, flux_list_new, growing=True)
    return np.nan if idx is None else r_list_new[idx]

# %%
def fraction_flux_to_r(r_list, flux_list, total_flux, fraction=0.5):
    """
    Given photometric values and `r_total_flux`, calculate radius which encloses a specified
    fraction of the total flux.

    Parameters
    ----------
    r_list : numpy.array
        Array of radii in pixels.

    flux_list : numpy.array
        Array of photometric flux values.

    r_total_flux : float
        Total flux radius (hint: `petrofit.petrosian.calculate_r_total_flux` can be used to measure this).

    fraction : float
        Fraction of flux total flux enclosed in target radius.

    Returns
    -------
    r_fraction_flux : float or numpy.nan
        Radius which encloses a specified fraction of the total flux (determined by the Petrosian profile).
    """

    fractional_flux = total_flux * fraction

    r_list_new, flux_list_new = r_list, flux_list

    # idx = abs(flux_list_new - fractional_flux).argmin()
    idx = closest_value_index(fractional_flux, flux_list_new, growing=True)
    return np.nan if idx is None else r_list_new[idx]

# %%
f = interp1d(r_list, flux_larr, kind='nearest')

# %%
plt.plot(r_list[:200], f(r_list[:200]))

# %%
def discrete_petrosian_r(r_list, area_list, flux_list, eta=0.2):
    """
    Calculate petrosian radius from photometric values by using the nearest value petrosian to eta.
    The petrosian radius is defined as the radius at which the petrosian profile equals eta.

    Parameters
    ----------
    r_list : numpy.array
        Array of radii in pixels.

    area_list : numpy.array
        Array of aperture areas.

    flux_list : numpy.array
        Array of photometric flux values.

    eta : float, default=0.2
        Eta is the petrosian value which defines the `r_petrosian`.

    Returns
    -------
    r_petrosian : float or numpy.nan
        Petrosian radius
    """

    petrosian_list = calculate_petrosian(area_list, flux_list)
    

    r_petrosian = np.nan
    if idx_list.size > 0:
        idx = idx_list[0]
        r_petrosian = r_list[idx]

    return r_petrosian

# %%
x, y = get_interpolated_values(r_list, flux_arr, kind='nearest')
plt.plot(x, y)

# %%
ot = t
